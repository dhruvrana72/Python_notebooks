# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from pandas.stats.api import ols
import seaborn as sns

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
data = pd.read_csv('bank_statement_analysis_for_all_users_v02.csv')

# %%
data.head()
# Out:
#    User Id  F10_median       F10_avg   F10_min    F10_max  N10_median  \
# 0       54   10777.195  17071.653800    175.58  102368.89    6561.755
# 1       26   89528.420  87071.956333  56300.11  104528.42   87664.125
# 2       83   13152.280  23514.759000     17.18  194223.54    1142.405
# 3      196   63065.740  63475.900000  62040.74   66924.04   50848.740
# 4      159    3805.000  20101.340000     71.86   57021.86    1382.500
#
#         N10_avg   N10_min    N10_max  L10_median    ...        SW_min  \
# 0  14477.381600     87.42  143710.89     2589.43    ...         87.42
# 1  87233.244167  70351.11  100862.77    88644.87    ...      70501.11
# 2   5013.652500      0.18   46725.54     2318.88    ...         17.18
# 3  50123.653000  34446.87   62040.74    27106.83    ...      61415.74
# 4  23908.240000    101.86  106764.86      383.50    ...        204.86
#
#       SW_max  TW_median        TW_avg    TW_min     TW_max  FW_median  \
# ...

# %%
data_copy = data

# %%
plt.scatter(data_copy['L10_median'], data_copy['FW_median'])
plt.xlabel('F10_median', fontsize=18)
plt.ylabel('N10_median', fontsize=16)
plt.show()

# %%
import statsmodels.api as sm
model = sm.OLS(data_copy['L10_median'],data_copy['FW_median'])

# %%
model
olsres = model.fit()
print(olsres.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             L10_median   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     1044.
# Date:                Mon, 21 Nov 2016   Prob (F-statistic):           3.62e-35
# Time:                        15:17:10   Log-Likelihood:                -519.55
# No. Observations:                  51   AIC:                             1041.
# Df Residuals:                      50   BIC:                             1043.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# FW_median      1.0322      0.032     32.312      0.000         0.968     1.096
# ...

# %%
a = data_copy.describe()

# %%
a
# Out:
#            User Id     F10_median        F10_avg        F10_min  \
# count    51.000000      51.000000      51.000000      51.000000
# mean    539.803922   20607.609314   27164.085434    8723.455882
# std     237.093317   34006.152295   45386.539547   24575.434570
# min      26.000000       0.000000     487.778667     -10.800000
# 25%     423.000000    2848.300000    5547.710000       1.205000
# 50%     541.000000    7851.150000   12656.436667      24.700000
# 75%     656.500000   17130.960000   21601.622833     262.530000
# max    1231.000000  146100.330000  264821.751000  103875.920000
#
#              F10_max     N10_median        N10_avg       N10_min  \
# count      51.000000      51.000000      51.000000     51.000000
# mean    73172.943333   14763.364314   19357.566793   5459.288235
# std    110961.791030   28328.807288   28531.731009  15907.718495
# min      3049.390000       3.590000     215.000000    -10.800000
# ...
